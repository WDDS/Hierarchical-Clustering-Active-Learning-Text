# %%
from Bio import Entrez
from pprint import pprint
import pandas as pd 
from collections import Counter

# %% [markdown]
# ### get mesh structure

# %%
import re
meshFile = '/home/adrian/PhD/Data/Pubmed/MeshCodes/d2020.bin'
uiMeshList = {}
NumberMeshList = {}
terms = {}
with open(meshFile, mode='r') as file:
    mesh = file.readlines()

    for i, line in enumerate(mesh):
        if "NEWRECORD" in line and i > 0 and ui is not "" and term is not "" and number is not "s":
            uiMeshList[UI] = {"MH" : term, "MN" : number }
            NumberMeshList[number] = {"MH" : term, "UI" : UI }
            ui = ""
            term = ""
            number = ""
        
                
        meshTerm = re.search('MH = (.+)$', line)
        if meshTerm:
            term = meshTerm.group(1)

        meshNumber = re.search('MN = (.+)$', line)
        if meshNumber:
            number = meshNumber.group(1)
            
        ui = re.search("UI = (.+)", line)
        if ui:
            UI = ui.group(1)

        
print(len(NumberMeshList.keys()))
diabetesMesh = {k:v for k,v in NumberMeshList.items() if k.startswith("C19.246")}
print(len(diabetesMesh.keys()))
diabetesMesh
# Out:
# 29638
# 16
# {'C19.246': {'MH': 'Diabetes Mellitus', 'UI': 'D003920'},
#  'C19.246.300.500': {'MH': 'Diabetes Mellitus, Lipoatrophic', 'UI': 'D003923'},
#  'C19.246.300': {'MH': 'Diabetes Mellitus, Type 2', 'UI': 'D003924'},
#  'C19.246.099.500': {'MH': 'Diabetic Angiopathies', 'UI': 'D003925'},
#  'C19.246.099.750': {'MH': 'Diabetic Coma', 'UI': 'D003926'},
#  'C19.246.099.875': {'MH': 'Diabetic Nephropathies', 'UI': 'D003928'},
#  'C19.246.099.937': {'MH': 'Diabetic Neuropathies', 'UI': 'D003929'},
#  'C19.246.099.500.382': {'MH': 'Diabetic Retinopathy', 'UI': 'D003930'},
#  'C19.246.099.750.490': {'MH': 'Hyperglycemic Hyperosmolar Nonketotic Coma',
#   'UI': 'D006944'},
#  'C19.246.774': {'MH': 'Prediabetic State', 'UI': 'D011236'},
#  'C19.246.200': {'MH': 'Diabetes, Gestational', 'UI': 'D016640'},
#  'C19.246.099.812': {'MH': 'Diabetic Ketoacidosis', 'UI': 'D016883'},
#  'C19.246.099.937.250': {'MH': 'Diabetic Foot', 'UI': 'D017719'},
#  'C19.246.099': {'MH': 'Diabetes Complications', 'UI': 'D048909'},
#  'C19.246.537': {'MH': 'Donohue Syndrome', 'UI': 'D056731'},
#  'C19.246.099.625': {'MH': 'Diabetic Cardiomyopathies', 'UI': 'D058065'}}

# %%
# Add missing diabetes mesh manually : https://meshb.nlm.nih.gov/treeView
diabetesMeshTotal = diabetesMesh.copy()
diabetesMeshTotal["C19.246.656"] = {"MH" :"Latent Autoimmune Diabetes in Adults", "UI":"D000071698"}
diabetesMeshTotal["C19.246.267.960"] = {"MH" :"Wolfram Syndrome", "UI":"D014929"}
diabetesMeshTotal["C19.246.267"] = {"MH" :"Diabetes Mellitus, Type 1", "UI":"D003922"}
diabetesMeshTotal["C19.246.240"] = {"MH" :"Diabetes Mellitus, Experimental", "UI":"D003921"}
diabetesMeshTotal["C19.246.099.968"] = {"MH" :"Fetal Macrosomia", "UI":"D005320"}
diabetesMeshTotal["C19.246.099.500.191"] = {"MH" :"Diabetic Foot", "UI":"D017719"}

print(len(diabetesMeshTotal))
diabetesMeshTotal
# Out:
# 22
# {'C19.246': {'MH': 'Diabetes Mellitus', 'UI': 'D003920'},
#  'C19.246.300.500': {'MH': 'Diabetes Mellitus, Lipoatrophic', 'UI': 'D003923'},
#  'C19.246.300': {'MH': 'Diabetes Mellitus, Type 2', 'UI': 'D003924'},
#  'C19.246.099.500': {'MH': 'Diabetic Angiopathies', 'UI': 'D003925'},
#  'C19.246.099.750': {'MH': 'Diabetic Coma', 'UI': 'D003926'},
#  'C19.246.099.875': {'MH': 'Diabetic Nephropathies', 'UI': 'D003928'},
#  'C19.246.099.937': {'MH': 'Diabetic Neuropathies', 'UI': 'D003929'},
#  'C19.246.099.500.382': {'MH': 'Diabetic Retinopathy', 'UI': 'D003930'},
#  'C19.246.099.750.490': {'MH': 'Hyperglycemic Hyperosmolar Nonketotic Coma',
#   'UI': 'D006944'},
#  'C19.246.774': {'MH': 'Prediabetic State', 'UI': 'D011236'},
#  'C19.246.200': {'MH': 'Diabetes, Gestational', 'UI': 'D016640'},
#  'C19.246.099.812': {'MH': 'Diabetic Ketoacidosis', 'UI': 'D016883'},
#  'C19.246.099.937.250': {'MH': 'Diabetic Foot', 'UI': 'D017719'},
#  'C19.246.099': {'MH': 'Diabetes Complications', 'UI': 'D048909'},
#  'C19.246.537': {'MH': 'Donohue Syndrome', 'UI': 'D056731'},
#  'C19.246.099.625': {'MH': 'Diabetic Cardiomyopathies', 'UI': 'D058065'},
#  'C19.246.656': {'MH': 'Latent Autoimmune Diabetes in Adults',
#   'UI': 'D000071698'},
#  'C19.246.267.960': {'MH': 'Wolfram Syndrome', 'UI': 'D014929'},
#  'C19.246.267': {'MH': 'Diabetes Mellitus, Type 1', 'UI': 'D003922'},
#  'C19.246.240': {'MH': 'Diabetes Mellitus, Experimental', 'UI': 'D003921'},
#  'C19.246.099.968': {'MH': 'Fetal Macrosomia', 'UI': 'D005320'},
#  'C19.246.099.500.191': {'MH': 'Diabetic Foot', 'UI': 'D017719'}}

# %%
diabetesMeshTotalInv = {v["UI"] : {"MN" : k, "MH" : v["MH"]} for k, v in diabetesMeshTotal.items()}
diabetesMeshTotalInv
# Out:
# {'D003920': {'MN': 'C19.246', 'MH': 'Diabetes Mellitus'},
#  'D003923': {'MN': 'C19.246.300.500', 'MH': 'Diabetes Mellitus, Lipoatrophic'},
#  'D003924': {'MN': 'C19.246.300', 'MH': 'Diabetes Mellitus, Type 2'},
#  'D003925': {'MN': 'C19.246.099.500', 'MH': 'Diabetic Angiopathies'},
#  'D003926': {'MN': 'C19.246.099.750', 'MH': 'Diabetic Coma'},
#  'D003928': {'MN': 'C19.246.099.875', 'MH': 'Diabetic Nephropathies'},
#  'D003929': {'MN': 'C19.246.099.937', 'MH': 'Diabetic Neuropathies'},
#  'D003930': {'MN': 'C19.246.099.500.382', 'MH': 'Diabetic Retinopathy'},
#  'D006944': {'MN': 'C19.246.099.750.490',
#   'MH': 'Hyperglycemic Hyperosmolar Nonketotic Coma'},
#  'D011236': {'MN': 'C19.246.774', 'MH': 'Prediabetic State'},
#  'D016640': {'MN': 'C19.246.200', 'MH': 'Diabetes, Gestational'},
#  'D016883': {'MN': 'C19.246.099.812', 'MH': 'Diabetic Ketoacidosis'},
#  'D017719': {'MN': 'C19.246.099.500.191', 'MH': 'Diabetic Foot'},
#  'D048909': {'MN': 'C19.246.099', 'MH': 'Diabetes Complications'},
#  'D056731': {'MN': 'C19.246.537', 'MH': 'Donohue Syndrome'},
#  'D058065': {'MN': 'C19.246.099.625', 'MH': 'Diabetic Cardiomyopathies'},
#  'D000071698': {'MN': 'C19.246.656',
#   'MH': 'Latent Autoimmune Diabetes in Adults'},
#  'D014929': {'MN': 'C19.246.267.960', 'MH': 'Wolfram Syndrome'},
#  'D003922': {'MN': 'C19.246.267', 'MH': 'Diabetes Mellitus, Type 1'},
#  'D003921': {'MN': 'C19.246.240', 'MH': 'Diabetes Mellitus, Experimental'},
#  'D005320': {'MN': 'C19.246.099.968', 'MH': 'Fetal Macrosomia'}}

# %% [markdown]
# ## Get pubmed articles

# %%
# get articles 
def search(query, Nhits=20):
    Entrez.email = 'a.ahne@epiconcept.fr'
    handle = Entrez.esearch(db='pubmed', 
                            sort='relevance', 
                            retmax=Nhits,
                            retmode='xml', 
                            term=query)
    results = Entrez.read(handle) # Parse an XML file from the NCBI Entrez Utilities into python objects
    return results


def fetch_details(id_list):
    ids = ','.join(id_list)
    Entrez.email = 'a.ahne@epiconcept.fr'
    handle = Entrez.efetch(db='pubmed',
                           retmode='xml',
                           id=ids)
    results = Entrez.read(handle) # Parse an XML file from the NCBI Entrez Utilities into python objects
    return results


def getMeshListFromDoc(doc): 
    matches = [match["DescriptorName"].attributes["UI"] 
               for match in doc["MedlineCitation"]["MeshHeadingList"]
               if match["DescriptorName"].attributes["UI"] in diabetesMeshTotalInv.keys()
              ]

    if len(matches) > 0 : 
        return matches
    else:
        return None

def parseDate(doc):
    if "DateCompleted" in doc.keys():
        return "{}-{}-{}".format(doc["DateCompleted"]["Year"], doc["DateCompleted"]["Month"], doc["DateCompleted"]["Day"])
    elif "DateRevised" in doc.keys():
        return "{}-{}-{}".format(doc["DateRevised"]["Year"], doc["DateRevised"]["Month"], doc["DateRevised"]["Day"])
    else:
        return None

def clean(doc):
    if "[" == doc[0]:
        doc = doc[1:]
    if "." == doc[-1]:
        doc = doc[0:-1]
    if "]" == doc[-1]:
        doc = doc[0:-1]
    return doc



Nhits = 10000
results = search('diabetes', Nhits)
print(len(results['IdList']))

id_list = results['IdList']
papers = fetch_details(id_list)
print(len(papers["PubmedArticle"]))

rows = []
for i, doc in enumerate(papers["PubmedArticle"]):
    
    if "MeshHeadingList" in doc["MedlineCitation"] and "Abstract" in doc["MedlineCitation"]["Article"]: 
        meshList = getMeshListFromDoc(doc)
        if meshList:
            rows.append({"PMID" : doc["MedlineCitation"]["PMID"]
                        ,"DateCompleted" : parseDate(doc["MedlineCitation"])
                        ,"Title" : clean(doc["MedlineCitation"]["Article"]["ArticleTitle"])
                        ,"Abstract" : doc["MedlineCitation"]["Article"]["Abstract"]["AbstractText"][0]
                        ,"MeshList" : meshList
                        })

diabetesArticles = pd.DataFrame(rows, columns=["PMID", "DateCompleted", "Title", "Abstract", "MeshList"])
diabetesArticles['DateCompleted'] =  pd.to_datetime(diabetesArticles['DateCompleted'], format='%Y-%m-%d')

print(diabetesArticles.shape)
diabetesArticles.head(50)
# Out:
# 10000
# 9997
# (7815, 5)
#         PMID DateCompleted                                              Title  \
# 0   29659364    2019-02-05  Association between central diabetes insipidus...
# 1   30071825    2019-05-21  Fatal Fournier's gangrene caused by Clostridiu...
# 2   21842608    2011-11-03  Case of distal renal tubular acidosis complica...
# 3   17026722    2007-01-01  The value of urine specific gravity in detecti...
# 4   25255707    2016-01-12  Congenital central diabetes insipidus and opti...
# 5   28588004    2018-05-23  Long-Term Follow-up of a Case with Proprotein ...
# 6   26783152    2016-10-17  Early central diabetes insipidus: An ominous s...
# 7   25301491    2016-10-31  False diagnosis of type 1 diabetes mellitus an...
# 8   17536072    2007-09-06  Microvascular diabetes complications in Wolfra...
# 9   25330715    2015-10-01  The spectrum of clinical presentation, diagnos...
# 10  20500966    2010-07-22  Gestational diabetes insipidus: a review of an...
# 11  23380272    2013-08-26  Gestational diabetes insipidus during a twin p...
# 12  31038066    2020-04-08  Relationship Between Hormonal Mechanisms of Di...
# 13  31884765    2020-01-23  The mortality of diabetes mellitus from the pe...
# 14  12516704    2003-01-24  Diabetes insipidus in a patient with diabetes ...
# 15  11402519    2001-07-05  A disseminated form of Langerhans histiocytosi...
# 16  32294829    2020-06-01  Relationship of body mass index, waist circumf...
# 17  32141596    2020-03-17  Prevalence and clinical characteristics of dia...
# 18  31692777    2019-11-25  Adherence to insulin therapy and associated fa...
# 19  30896392    2019-11-07  Prescribing of Non-Steroidal Anti-Inflammatory...
# 20  30623669    2019-12-06  Aortic stenosis and diabetes mellitus: An omin...
# 21  30712377    2019-12-06  Metformin decreases the risk of sudden sensori...
# 22  30203902    2019-12-31  Lichen planus and diabetes mellitus: Systemati...
# 23  31601311    2019-11-12  Prevalence and the relevant factors of type 2 ...
# 24  31820841    2020-06-08  Assessing the association between optimal ener...
# 25  30276959    2020-02-13  Intention-to-treat analysis of liver transplan...
# 26  31146665    2020-04-08  The Worrying Trend of Diabetes Mellitus in Sau...
# 27  30948803    2019-07-17  Improving pregnancy outcomes in women with dia...
# 28  30706825    2020-02-24  In Silico Computations of Selective Phytochemi...
# 29  31588541    2019-10-09               Monogenic Forms of Diabetes Mellitus
# 30  30648511    2020-02-07  Type-3c Diabetes Mellitus, Diabetes of Exocrin...
# 31  30563474    2019-06-07  Perceived family support among older persons i...
# 32  29946761    2019-10-09  Effects of Diabetes Mellitus and Admission Glu...
# 33  30426486    2020-04-08  A review of the molecular pathways mediating t...
# 34  31781641    2020-04-09  Diabetes Mellitus among Adult Tuberculosis Pat...
# 35  31743349    2020-03-23  Factors associated with medication adherence a...
# 36  28963756    2018-10-26  Assessing a new hip index as a risk predictor ...
# 37  31065905    2020-03-18  Diabetes mellitus is associated with dry eye s...
# 38  30980168    2019-09-16  Mental disorders and diabetes mellitus (Update...
# 39  30396368    2019-02-11  Association between helminth infections and di...
# 40  31852461    2020-05-19  Prevalence of sexual dysfunction and related f...
# 41  25646595    2015-12-17  Transsphenoidal surgery and diabetes mellitus:...
# 42  27414478    2017-05-17  Partial Nephrogenic Diabetes Insipidus in a Bu...
# 43  31183383    2020-01-13  The Burden of Undiagnosed Diabetes Mellitus in...
# 44  31057116    2020-02-17  Knowledge and Awareness of Oral Manifestations...
# 45  31366392    2020-01-30  Iranian neonatal diabetes mellitus due to muta...
# 46  31604444    2020-05-26  Hypomagnesemia is associated with new-onset di...
# 47  31069497    2019-12-24  The impact of diabetes mellitus on clinical ou...
# 48  31423559    2020-01-13  The multifaceted nature of diabetes mellitus i...
# 49  31615566    2020-03-12  Predictive models for diabetes mellitus using ...
#
#                                              Abstract  \
# 0   Central diabetes insipidus is a rare disease o...
# 1   Clostridium ramosum is a generally non-pathoge...
# 2   We report herein a 27-year-old male case of in...
# 3   When a patient with diabetes mellitus presents...
# 4   Wolfram syndrome (WS) is an autosomal recessiv...
# 5   Proprotein convertase 1/3 (PC1/3) deficiency i...
# 6   Central diabetes insipidus (CDI) after cardiac...
# 7   Wolfram syndrome (WS), also known as DIDMOAD (...
# 8   Some previous studies suggested that patients ...
# 9   Primary mitochondrial diseases refer to a grou...
# 10  To review the etiology, diagnosis, and managem...
# 11  Gestational diabetes insipidus is an uncommon ...
# 12  Obesity, diabetes mellitus may be related to t...
# 13  The statistics of causes of death is the infor...
# 14  The association of Diabetes Mellitus (DM) and ...
# 15  Langerhans' cell histiocytosis is a rare disor...
# 16  <b>Objective:</b> To analyze the relationship ...
# 17  Diabetes mellitus in all its forms has been ra...
# 18  Adherence to insulin therapy is a critical fac...
# 19  Portugal presents the highest incidence of sta...
# 20  Aortic stenosis and diabetes mellitus are both...
# 21  The risk of sudden sensorineural hearing loss ...
# 22  The aim of this study was to perform a systema...
# 23  To investigate the prevalence and relevant fac...
# 24  Selecting optimal energy intake during diet th...
# 25  Diabetes mellitus is known to negatively impac...
# 26  From last few years, the pervasiveness of diab...
# 27  Women with pre-existing (type 1 or type 2) dia...
# 28  In the past few years, several developments ha...
# 29  In addition to the common types of diabetes me...
# 30  The incidence of diabetes is increasing steepl...
# 31  The aging process has functional consequences ...
# 32  We performed a meta-analysis to evaluate the o...
# 33  Lifestyle modification is the cornerstone of d...
# 34  Developing countries are suffering from the pr...
# 35  In Cambodia, the age-standardized prevalence o...
# 36  Recently, a new anthropometric parameter (a ne...
# 37  Dry eye is the most common eye disorder of tea...
# 38  Psychiatric disorders and psychological proble...
# 39  As a result of epidemiological transition, the...
# 40  Diabetes mellitus causes multiple medical, psy...
# 41  Transsphenoidal surgery (TSS) has emerged as t...
# 42  To describe a case of partial nephrogenic diab...
# 43  The prevalence of diabetes is rapidly increasi...
# 44  Diabetes mellitus has increased rapidly throug...
# 45  Neonatal diabetes mellitus with hyperglycemia ...
# 46  Diabetes mellitus (DM) is a major cause of mor...
# 47  A meta-analysis was performed to evaluate the ...
# 48  Immune checkpoint inhibitors (CPI) are increas...
# 49  Diabetes Mellitus is an increasingly prevalent...
#
#                        MeshList
# 0                     [D003924]
# 1                     [D003922]
# 2                     [D048909]
# 3                     [D003924]
# 4                     [D014929]
# 5            [D003920, D016883]
# 6            [D058065, D003928]
# 7            [D003922, D014929]
# 8            [D003925, D014929]
# 9                     [D003920]
# 10                    [D016640]
# 11                    [D016640]
# 12                    [D003920]
# 13                    [D003920]
# 14                    [D003924]
# 15                    [D003920]
# 16                    [D003920]
# 17  [D048909, D003920, D003922]
# 18                    [D003920]
# 19                    [D003920]
# 20                    [D003920]
# 21                    [D003920]
# 22           [D048909, D003920]
# 23           [D003920, D003924]
# 24                    [D003924]
# 25                    [D003920]
# 26           [D048909, D003920]
# 27                    [D003920]
# 28                    [D003920]
# 29           [D003920, D003924]
# 30           [D003920, D003924]
# 31                    [D003920]
# 32                    [D003920]
# 33           [D003920, D003924]
# 34                    [D003920]
# 35                    [D003920]
# 36                    [D003920]
# 37                    [D003920]
# 38           [D048909, D003920]
# 39                    [D003920]
# 40           [D048909, D003920]
# 41                    [D048909]
# 42                    [D003928]
# 43                    [D003920]
# 44                    [D003924]
# 45                    [D003920]
# 46                    [D003920]
# 47           [D048909, D003920]
# 48  [D003923, D003922, D003924]
# 49                    [D003920]

# %%
flat_list = [code for meshlist in diabetesArticles["MeshList"].values for code in meshlist]
print(len(flat_list))
Counter(flat_list)
# Out:
# 10378
# Counter({'D003924': 4486,
#          'D003922': 1186,
#          'D048909': 622,
#          'D014929': 13,
#          'D003920': 1908,
#          'D016883': 68,
#          'D058065': 74,
#          'D003928': 216,
#          'D003925': 231,
#          'D016640': 700,
#          'D003923': 2,
#          'D011236': 154,
#          'D003921': 374,
#          'D003929': 123,
#          'D017719': 33,
#          'D006944': 4,
#          'D003930': 141,
#          'D005320': 38,
#          'D056731': 1,
#          'D000071698': 4})

# %% [markdown]
# ### keep only records with one diabetes mesh code (need to reduce the dataset to be able to run it)

# %%
# keep only records with one diabetes Mesh code

diabArtOneMesh = diabetesArticles[diabetesArticles.apply(lambda row: len(row["MeshList"]) == 1
                                                                      , axis=1)]
diabArtOneMesh["MeshUI"] = diabArtOneMesh["MeshList"].map(lambda x: x[0]) # list entry to string
diabArtOneMesh["MeshNumber"] = diabArtOneMesh.apply(lambda row: diabetesMeshTotalInv[row["MeshUI"]]["MN"], axis=1)
diabArtOneMesh["MeshHeading"] = diabArtOneMesh.apply(lambda row: diabetesMeshTotalInv[row["MeshUI"]]["MH"], axis=1)
del diabArtOneMesh["MeshList"]
print(diabArtOneMesh.shape)
diabArtOneMesh.head(50)
# Out:
# (5665, 7)
# /home/adrian/miniconda3/envs/deepscience/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/adrian/miniconda3/envs/deepscience/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adrian/miniconda3/envs/deepscience/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#         PMID DateCompleted                                              Title  \
# 0   29659364    2019-02-05  Association between central diabetes insipidus...
# 1   30071825    2019-05-21  Fatal Fournier's gangrene caused by Clostridiu...
# 2   21842608    2011-11-03  Case of distal renal tubular acidosis complica...
# 3   17026722    2007-01-01  The value of urine specific gravity in detecti...
# 4   25255707    2016-01-12  Congenital central diabetes insipidus and opti...
# 9   25330715    2015-10-01  The spectrum of clinical presentation, diagnos...
# 10  20500966    2010-07-22  Gestational diabetes insipidus: a review of an...
# 11  23380272    2013-08-26  Gestational diabetes insipidus during a twin p...
# 12  31038066    2020-04-08  Relationship Between Hormonal Mechanisms of Di...
# 13  31884765    2020-01-23  The mortality of diabetes mellitus from the pe...
# 14  12516704    2003-01-24  Diabetes insipidus in a patient with diabetes ...
# 15  11402519    2001-07-05  A disseminated form of Langerhans histiocytosi...
# 16  32294829    2020-06-01  Relationship of body mass index, waist circumf...
# 18  31692777    2019-11-25  Adherence to insulin therapy and associated fa...
# 19  30896392    2019-11-07  Prescribing of Non-Steroidal Anti-Inflammatory...
# 20  30623669    2019-12-06  Aortic stenosis and diabetes mellitus: An omin...
# 21  30712377    2019-12-06  Metformin decreases the risk of sudden sensori...
# 24  31820841    2020-06-08  Assessing the association between optimal ener...
# 25  30276959    2020-02-13  Intention-to-treat analysis of liver transplan...
# 27  30948803    2019-07-17  Improving pregnancy outcomes in women with dia...
# 28  30706825    2020-02-24  In Silico Computations of Selective Phytochemi...
# 31  30563474    2019-06-07  Perceived family support among older persons i...
# 32  29946761    2019-10-09  Effects of Diabetes Mellitus and Admission Glu...
# 34  31781641    2020-04-09  Diabetes Mellitus among Adult Tuberculosis Pat...
# 35  31743349    2020-03-23  Factors associated with medication adherence a...
# 36  28963756    2018-10-26  Assessing a new hip index as a risk predictor ...
# 37  31065905    2020-03-18  Diabetes mellitus is associated with dry eye s...
# 39  30396368    2019-02-11  Association between helminth infections and di...
# 41  25646595    2015-12-17  Transsphenoidal surgery and diabetes mellitus:...
# 42  27414478    2017-05-17  Partial Nephrogenic Diabetes Insipidus in a Bu...
# 43  31183383    2020-01-13  The Burden of Undiagnosed Diabetes Mellitus in...
# 44  31057116    2020-02-17  Knowledge and Awareness of Oral Manifestations...
# 45  31366392    2020-01-30  Iranian neonatal diabetes mellitus due to muta...
# 46  31604444    2020-05-26  Hypomagnesemia is associated with new-onset di...
# 49  31615566    2020-03-12  Predictive models for diabetes mellitus using ...
# 52  29193646    2018-09-24  Quantifying the hidden healthcare cost of diab...
# 54  30293242    2019-06-04  Hypertension and diabetes mellitus are not ass...
# 55  31256067    2020-04-28  In-hospital screening for diabetes mellitus wi...
# 56  30634972    2019-04-23  Improved outcome of patients with diabetes mel...
# 58  29719968    2019-09-11  Association of baseline level of physical acti...
# 59  29777621    2019-02-14  Serum high-density lipoprotein cholesterol is ...
# 61  31045823    2019-05-10  Real-world database investigating the associat...
# 62  29421689    2019-08-29  Diabetes Mellitus Associates with Increased Ri...
# 63  30738330    2020-03-31  The management of diabetes mellitus-imperative...
# 64  29330255    2019-09-24  High-Intensity Cigarette Smoking Is Associated...
# 65  31299990    2020-03-30  Carotid ultrasound investigation as a prognost...
# 67  30064147    2019-10-24  Assessment of the Influence of Diabetes mellit...
# 68  28709853    2018-08-08  Evaluation of current trends and recent develo...
# 70  30285859    2019-01-23  An open-label pilot study on preventing glucoc...
# 72  28847886    2017-10-20  Hypertension Control in Adults With Diabetes M...
#
#                                              Abstract   MeshUI  \
# 0   Central diabetes insipidus is a rare disease o...  D003924
# 1   Clostridium ramosum is a generally non-pathoge...  D003922
# 2   We report herein a 27-year-old male case of in...  D048909
# 3   When a patient with diabetes mellitus presents...  D003924
# 4   Wolfram syndrome (WS) is an autosomal recessiv...  D014929
# 9   Primary mitochondrial diseases refer to a grou...  D003920
# 10  To review the etiology, diagnosis, and managem...  D016640
# 11  Gestational diabetes insipidus is an uncommon ...  D016640
# 12  Obesity, diabetes mellitus may be related to t...  D003920
# 13  The statistics of causes of death is the infor...  D003920
# 14  The association of Diabetes Mellitus (DM) and ...  D003924
# 15  Langerhans' cell histiocytosis is a rare disor...  D003920
# 16  <b>Objective:</b> To analyze the relationship ...  D003920
# 18  Adherence to insulin therapy is a critical fac...  D003920
# 19  Portugal presents the highest incidence of sta...  D003920
# 20  Aortic stenosis and diabetes mellitus are both...  D003920
# 21  The risk of sudden sensorineural hearing loss ...  D003920
# 24  Selecting optimal energy intake during diet th...  D003924
# 25  Diabetes mellitus is known to negatively impac...  D003920
# 27  Women with pre-existing (type 1 or type 2) dia...  D003920
# 28  In the past few years, several developments ha...  D003920
# 31  The aging process has functional consequences ...  D003920
# 32  We performed a meta-analysis to evaluate the o...  D003920
# 34  Developing countries are suffering from the pr...  D003920
# 35  In Cambodia, the age-standardized prevalence o...  D003920
# 36  Recently, a new anthropometric parameter (a ne...  D003920
# 37  Dry eye is the most common eye disorder of tea...  D003920
# 39  As a result of epidemiological transition, the...  D003920
# 41  Transsphenoidal surgery (TSS) has emerged as t...  D048909
# 42  To describe a case of partial nephrogenic diab...  D003928
# 43  The prevalence of diabetes is rapidly increasi...  D003920
# 44  Diabetes mellitus has increased rapidly throug...  D003924
# 45  Neonatal diabetes mellitus with hyperglycemia ...  D003920
# 46  Diabetes mellitus (DM) is a major cause of mor...  D003920
# 49  Diabetes Mellitus is an increasingly prevalent...  D003920
# 52  Diabetes mellitus in hospital inpatients is mo...  D003920
# 54  To analyze the association of hypertension and...  D003920
# 55  Screening inpatients for diabetes mellitus may...  D003920
# 56  Diabetes mellitus (DM) is a prevalent metaboli...  D003920
# 58  Background The association between baseline an...  D003920
# 59  Older people with diabetes mellitus are at hig...  D003920
# 61  Little evidence is available about the correla...  D003920
# 62  Diabetes mellitus is associated with left vent...  D003920
# 63  Diabetes mellitus is a chronic metabolic disor...  D003920
# 64  Previous reports on whether smoking is associa...  D003920
# 65  Experimental and clinical data indicate a majo...  D003920
# 67  The prevalence of diabetes mellitus (DM) or ma...  D003920
# 68  Diabetes mellitus is a major health problem in...  D003920
# 70  Numerous patients develop diabetes in response...  D003920
# 72  Systolic blood pressure (SBP) treatment target...  D003920
#
#          MeshNumber                MeshHeading
# 0       C19.246.300  Diabetes Mellitus, Type 2
# 1       C19.246.267  Diabetes Mellitus, Type 1
# 2       C19.246.099     Diabetes Complications
# 3       C19.246.300  Diabetes Mellitus, Type 2
# 4   C19.246.267.960           Wolfram Syndrome
# 9           C19.246          Diabetes Mellitus
# 10      C19.246.200      Diabetes, Gestational
# 11      C19.246.200      Diabetes, Gestational
# 12          C19.246          Diabetes Mellitus
# 13          C19.246          Diabetes Mellitus
# 14      C19.246.300  Diabetes Mellitus, Type 2
# 15          C19.246          Diabetes Mellitus
# 16          C19.246          Diabetes Mellitus
# 18          C19.246          Diabetes Mellitus
# 19          C19.246          Diabetes Mellitus
# 20          C19.246          Diabetes Mellitus
# 21          C19.246          Diabetes Mellitus
# 24      C19.246.300  Diabetes Mellitus, Type 2
# 25          C19.246          Diabetes Mellitus
# 27          C19.246          Diabetes Mellitus
# 28          C19.246          Diabetes Mellitus
# 31          C19.246          Diabetes Mellitus
# 32          C19.246          Diabetes Mellitus
# 34          C19.246          Diabetes Mellitus
# 35          C19.246          Diabetes Mellitus
# 36          C19.246          Diabetes Mellitus
# 37          C19.246          Diabetes Mellitus
# 39          C19.246          Diabetes Mellitus
# 41      C19.246.099     Diabetes Complications
# 42  C19.246.099.875     Diabetic Nephropathies
# 43          C19.246          Diabetes Mellitus
# 44      C19.246.300  Diabetes Mellitus, Type 2
# 45          C19.246          Diabetes Mellitus
# 46          C19.246          Diabetes Mellitus
# 49          C19.246          Diabetes Mellitus
# 52          C19.246          Diabetes Mellitus
# 54          C19.246          Diabetes Mellitus
# 55          C19.246          Diabetes Mellitus
# 56          C19.246          Diabetes Mellitus
# 58          C19.246          Diabetes Mellitus
# 59          C19.246          Diabetes Mellitus
# 61          C19.246          Diabetes Mellitus
# 62          C19.246          Diabetes Mellitus
# 63          C19.246          Diabetes Mellitus
# 64          C19.246          Diabetes Mellitus
# 65          C19.246          Diabetes Mellitus
# 67          C19.246          Diabetes Mellitus
# 68          C19.246          Diabetes Mellitus
# 70          C19.246          Diabetes Mellitus
# 72          C19.246          Diabetes Mellitus

# %%
Counter(diabArtOneMesh["MeshHeading"].values)
# Out:
# Counter({'Diabetes Mellitus, Type 2': 3065,
#          'Diabetes Mellitus, Type 1': 531,
#          'Diabetes Complications': 92,
#          'Wolfram Syndrome': 3,
#          'Diabetes Mellitus': 1390,
#          'Diabetes, Gestational': 449,
#          'Diabetic Nephropathies': 5,
#          'Prediabetic State': 1,
#          'Diabetes Mellitus, Experimental': 112,
#          'Diabetic Angiopathies': 5,
#          'Diabetic Cardiomyopathies': 1,
#          'Diabetic Neuropathies': 6,
#          'Diabetic Foot': 3,
#          'Diabetic Retinopathy': 1,
#          'Fetal Macrosomia': 1})

# %%
#train = diabArtOneMesh[(diabArtOneMesh["MeshHeading"] =="Diabetes Mellitus, Type 1") | (diabArtOneMesh["MeshHeading"] == "Diabetes Complications") ]
train = diabArtOneMesh[(diabArtOneMesh["MeshHeading"] == "Diabetes Complications")
                       | (diabArtOneMesh["MeshHeading"] == "Diabetes, Gestational")
                       | (diabArtOneMesh["MeshHeading"] == "Diabetes Mellitus, Experimental")] \
        .append(diabArtOneMesh[diabArtOneMesh["MeshHeading"] == "Diabetes Mellitus, Type 2"].sample(n=200)) \
        .append(diabArtOneMesh[diabArtOneMesh["MeshHeading"] == "Diabetes Mellitus"].sample(n=200)) \
        .append(diabArtOneMesh[diabArtOneMesh["MeshHeading"] == "Diabetes Mellitus, Type 1"].sample(n=200))
 
#train = train.append(diabArtOneMesh[diabArtOneMeshtOneMesh["MeshHeading"] == "Diabetes Mellitus, Type 2"].sample(n=500))
print(train.shape)
train.head()
# Out:
# (1253, 7)
#          PMID DateCompleted  \
# 2    21842608    2011-11-03
# 10   20500966    2010-07-22
# 11   23380272    2013-08-26
# 41   25646595    2015-12-17
# 171  30866836    2019-04-26
#
#                                                  Title  \
# 2    Case of distal renal tubular acidosis complica...
# 10   Gestational diabetes insipidus: a review of an...
# 11   Gestational diabetes insipidus during a twin p...
# 41   Transsphenoidal surgery and diabetes mellitus:...
# 171  Prevalence of diabetes mellitus among tubercul...
#
#                                               Abstract   MeshUI   MeshNumber  \
# 2    We report herein a 27-year-old male case of in...  D048909  C19.246.099
# 10   To review the etiology, diagnosis, and managem...  D016640  C19.246.200
# 11   Gestational diabetes insipidus is an uncommon ...  D016640  C19.246.200
# 41   Transsphenoidal surgery (TSS) has emerged as t...  D048909  C19.246.099
# 171  Tuberculosis and diabetes mellitus are signifi...  D048909  C19.246.099
#
#                 MeshHeading
# 2    Diabetes Complications
# 10    Diabetes, Gestational
# 11    Diabetes, Gestational
# 41   Diabetes Complications
# 171  Diabetes Complications

# %%
train.to_parquet("/home/adrian/PhD/Data/Pubmed/diabetes_test_abstracts.parquet")

# %% [markdown]
# ## Remove documents who have the root class :  "D003920", "Diabetes Mellitus", "C19.246"

# %%
import pandas as pd
data = pd.read_parquet("/home/adrian/PhD/Data/Pubmed/baseline_diabetes_unique_maxNperClass5000.parquet")
data.head(2)
# Out:
#        PMID                                              title  \
# 0  28800712  Outcomes Achieved With Use of a Prefabricated ...
# 1   6989594  Investigation of insulin sensitivity in early ...
#
#                                             abstract     date  \
# 0  BACKGROUND\nThe total contact cast (TCC) is co...  2017-10
# 1  Twenty-three normal weight subjects without an...  1980-01
#
#                                              mesh_ui  \
# 0  D000328,D000367,D000368,D000369,D002370,D01533...
# 1  D001786,D001835,D005230,D005951,D006801,D00732...
#
#                                              mesh_mh mesh_ui_diab  \
# 0  Adult,Age Factors,Aged,Aged, 80 and over,Casts...      D017719
# 1  Blood Glucose,Body Weight,Fatty Acids, Noneste...      D011236
#
#         mesh_mh_diab                                title_abstract_prep
# 0      Diabetic Foot  outcomes achieved with use of a prefabricated ...
# 1  Prediabetic State  investigation of insulin sensitivity in early ...

# %%
print(data.shape)
data2 = data[data["mesh_mh_diab"] != "Diabetes Mellitus"]
print(data2.shape)
# Out:
# (55911, 9)
# (50911, 9)

# %%
data2.to_parquet("/home/adrian/PhD/Data/Pubmed/baseline_diabetes_unique_maxNperClass5000_withoutRootClassDiabetesMellitus.parquet")

# %%
import pandas as pd 
data = pd.read_parquet("/home/adrian/PhD/Data/Pubmed/baseline_diabetes_unique_maxNperClass5000_withoutRootClassDiabetesMellitus.parquet")
print(data.shape)
data.head(2)
# Out:
# (50911, 11)
#        PMID                                              title  \
# 0  28800712  Outcomes Achieved With Use of a Prefabricated ...
# 1   6989594  Investigation of insulin sensitivity in early ...
#
#                                             abstract     date  \
# 0  BACKGROUND\nThe total contact cast (TCC) is co...  2017-10
# 1  Twenty-three normal weight subjects without an...  1980-01
#
#                                              mesh_ui  \
# 0  D000328,D000367,D000368,D000369,D002370,D01533...
# 1  D001786,D001835,D005230,D005951,D006801,D00732...
#
#                                              mesh_mh mesh_ui_diab  \
# 0  Adult,Age Factors,Aged,Aged, 80 and over,Casts...      D017719
# 1  Blood Glucose,Body Weight,Fatty Acids, Noneste...      D011236
#
#         mesh_mh_diab                                title_abstract_prep  \
# 0      Diabetic Foot  outcomes achieved with use of a prefabricated ...
# 1  Prediabetic State  investigation of insulin sensitivity in early ...
#
#                                                  vec  \
# 0  [-0.1456865, 0.10184939, 0.08282469, 0.0834905...
# 1  [-0.13539475, 0.06387955, 0.0704756, 0.1377651...
#
#       mesh_ui_diab_with_childs
# 0  [D003925, D003929, D048909]
# 1                           []

# %%
diab_gestational = data[data["mesh_ui_diab"] == "D016640"].sample(n=1000, random_state=0)
diab_nonGestational = data[data["mesh_ui_diab"] != "D016640"].sample(n=1000, random_state=0)
diab_complications = data[data["mesh_ui_diab"] == "D048909"].sample(n=1000, random_state=0)
diab_nonComplications = data[data["mesh_ui_diab"] != "D048909"].sample(n=1000, random_state=0)
data_2000_random = data.sample(n=2000, random_state=0).reset_index(drop=True)
data_5000_random = data.sample(n=5000, random_state=0).reset_index(drop=True)
data_10000_random = data.sample(n=10000, random_state=0).reset_index(drop=True)
data_20000_random = data.sample(n=20000, random_state=0).reset_index(drop=True)
data_30000_random = data.sample(n=30000, random_state=0).reset_index(drop=True)
data_40000_random = data.sample(n=40000, random_state=0).reset_index(drop=True)
data_50000_random = data.sample(n=50000, random_state=0).reset_index(drop=True)

# %%
data_2000_random = data.sample(n=2000, random_state=0).reset_index(drop=True)

# %%
diab_gestational_nonGestational = diab_gestational.append(diab_nonGestational).sample(frac=1).reset_index(drop=True)
diab_complications_nonComplications = diab_complications.append(diab_nonComplications).sample(frac=1).reset_index(drop=True)

# %%
dirpath = "/home/adrian/workspace/ActiveLearning/Active-Learning-for-Neural-Networks/data/diabetes"
#subdir_gest = dirpath+"/gestational_1000pos_and_neg_samples/"
subdir_complications = dirpath+"/complications_100pos_and_neg_samples/"
#(diab_gestational.title + " " + diab_gestational.abstract).map(lambda s: s.replace('\n', '')).to_csv(subdir_gest+"diab_gestational_1000samples.txt", index=False, header=False)
#(diab_nonGestational.title + " " + diab_nonGestational.abstract).map(lambda s: s.replace('\n', '')).to_csv(subdir_gest+"diab_Nongestational_1000samples.txt", index=False, header=False)
#(diab_gestational.title ).map(lambda s: s.replace('\n', '')).to_csv(dirpath+"/gestational_1000pos_and_neg_samples_onlyTitles/diab_gestational_1000samples_onlyTitles.txt", index=False, header=False)
#(diab_nonGestational.title).map(lambda s: s.replace('\n', '')).to_csv(dirpath+"/gestational_1000pos_and_neg_samples_onlyTitles/diab_Nongestational_1000samples_onlyTitles.txt", index=False, header=False)
#(diab_complications.title + " " + diab_complications.abstract).map(lambda s: s.replace('\n', '')).to_csv(subdir_complications+"/diab_complications_1000samples.txt", index=False, header=False)
#(diab_nonComplications.title + " " + diab_nonComplications.abstract).map(lambda s: s.replace('\n', '')).to_csv(subdir_complications+"/diab_nonComplications_1000samples.txt", index=False, header=False)
#(diab_complications.title ).map(lambda s: s.replace('\n', '')).to_csv(dirpath+"/complications_1000pos_and_neg_samples_onlyTitles/diab_complications_1000samples_onlyTitles.txt", index=False, header=False)
#(diab_nonComplications.title).map(lambda s: s.replace('\n', '')).to_csv(dirpath+"/complications_1000pos_and_neg_samples_onlyTitles/diab_nonComplications_1000samples_onlyTitles.txt", index=False, header=False)

#diab_gestational_nonGestational.to_parquet(subdir_gest+"data.parquet")
#diab_complications_nonComplications.to_parquet(subdir_complications+"data.parquet")
#diab_complications_nonComplications.to_parquet("/home/adrian/workspace/Hierarchical-Clustering-Active-Learning-Text/tmp/complications_1000pos_and_neg_samples.parquet")
data_2000_random.to_parquet(dirpath+"/2000_random/2000_random_abstracts.parquet")
data_5000_random.to_parquet(dirpath+"/5000_random/5000_random_abstracts.parquet")
#dirpath = "/home/adrian/PhD/Data/Pubmed/baseline_diabetes_unique_maxNperClass5000_withoutRootClassDiabetesMellitus"
#data_5000_random.to_parquet(dirpath+"_sample5000.parquet")
#data_10000_random.to_parquet(dirpath+"_sample10000.parquet")
#data_20000_random.to_parquet(dirpath+"_sample20000.parquet")
#data_30000_random.to_parquet(dirpath+"_sample30000.parquet")
#data_40000_random.to_parquet(dirpath+"_sample40000.parquet")
#data_50000_random.to_parquet(dirpath+"_sample50000.parquet")

# %% [markdown]
# ### Get occurrences of abstracts per class

# %%
import pandas as pd
from collections import Counter

test = pd.read_parquet("/home/adrian/PhD/Data/Pubmed/baseline_diabetes_unique_maxNperClass5000_withoutRootClassDiabetesMellitus.parquet")
test.head(2)
Counter(test["mesh_mh_diab"].values)
# Out:
# Counter({'Diabetic Foot': 4424,
#          'Prediabetic State': 1261,
#          'Diabetic Neuropathies': 3662,
#          'Diabetes, Gestational': 5000,
#          'Diabetes Mellitus, Experimental': 5000,
#          'Diabetes Complications': 5000,
#          'Diabetes Mellitus, Type 2': 5000,
#          'Diabetic Retinopathy': 5000,
#          'Diabetes Mellitus, Type 1': 5000,
#          'Diabetic Angiopathies': 3026,
#          'Diabetic Ketoacidosis': 1308,
#          'Diabetic Nephropathies': 5000,
#          'Hyperglycemic Hyperosmolar Nonketotic Coma': 97,
#          'Fetal Macrosomia': 1282,
#          'Diabetic Cardiomyopathies': 386,
#          'Diabetic Coma': 97,
#          'Diabetes Mellitus, Lipoatrophic': 85,
#          'Wolfram Syndrome': 228,
#          'Donohue Syndrome': 39,
#          'Latent Autoimmune Diabetes in Adults': 16})

# %% [markdown]
# ### Get sample of diabetes tweets

# %%
import pandas as pd
import pyspark
spark = pyspark.sql.SparkSession.builder.getOrCreate()
data = spark.read.parquet("/home/adrian/PhD/Data/Tweets20190708/matching-tweets_diab_noRT-noBots_personal_noJokes_locationUS_geoCityCodeNotNull_emotions_gender-typeDiab_repartition6.parquet")
print(data.count())
print(data.show())
#data = pd.read_parquet("/home/adrian/PhD/Data/Tweets20190708/matching-tweets_diab_noRT-noBots_personal_noJokes_locationUS_geoCityCodeNotNull_emotions_gender-typeDiab_repartition6.parquet")
#print(data.shape)
#data.head(2)
# Out:
# 46407
# +--------------------+--------------------+----+--------------------+--------------------+----------------+--------------------+------------------+--------------------+--------------------+---------------+-------------------+--------------------------+------------------------------+----------------------------+-----------------------+--------------------------+-------------------------+--------------+------------+--------------------+--------------------+-------+----------------+--------+--------+----------------+-------------+-------------+-------------+-------------+-------------+------------------+----------+--------------------+------------+----------+------+------------+
# |                  id|          created_at|lang|                text|           user_name|user_screen_name|user_followers_count|user_friends_count|       user_location|    user_description|place_full_name|retweeted_user_name|retweeted_user_screen_name|retweeted_user_followers_count|retweeted_user_friends_count|retweeted_user_location|retweeted_user_description|retweeted_place_full_name|retweeted_text|posted_month|      tweet_URL_USER|   __index_level_0__| geo_id|        geo_name|geo_code|geo_type|geo_country_code|geo_city_code|geo_adm1_code|geo_adm2_code|geo_adm3_code|geo_adm4_code|               pop|   _score_|              _tags_|_startIndex_|_endIndex_|gender|typeDiabetes|
# +--------------------+--------------------+----+--------------------+--------------------+----------------+--------------------+------------------+--------------------+--------------------+---------------+-------------------+--------------------------+------------------------------+----------------------------+-----------------------+--------------------------+-------------------------+--------------+------------+--------------------+--------------------+-------+----------------+--------+--------+----------------+-------------+-------------+-------------+-------------+-------------+------------------+----------+--------------------+------------+----------+------+------------+
# |8.943158139304919E17|Sun Aug 06 21:54:...|  en|im getting a lice...|       boy. {pinned}|     kimhandsoap|               235.0|             451.0|         Houston, TX|smoke up a glimps...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201708.0|im getting a lice...|       boy. {pinned}|4699066|         Houston| 4699066|   PPLA2|              US|      4699066|           TX|          201|         null|         null|1.6651122112994687| 226.93657|          Houston,TX|           0|         2|     0|           0|
# |8.979126693191557...|Wed Aug 16 20:07:...|  en|@chrisbrighty @me...| understudy pancreas|  understudypanc|              3570.0|            2813.0|            Somerset|Failed to grow up...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201708.0|USER USER all goo...| understudy pancreas|5104755|        Somerset| 5104755|     PPL|              US|      5104755|           NJ|          035|         null|         null| 1.237608157381756|108.151306|            Somerset|           0|         1|     2|           1|
# |1.120798437694427...|Tue Apr 23 21:15:...|  en|@CPojoni @DHertzL...|     Cynthia Thurlow|     CHTWellness|              3452.0|             375.0|      Washington, DC|Nurse Practitione...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201904.0|USER USER USER Th...|     Cynthia Thurlow|4140963|Washington, D.C.| 4140963|    PPLC|              US|      4140963|           DC|          001|         null|         null| 1.532403484465457| 431.78375|       Washington,DC|           0|         2|     1|           0|
# |9.766353628554854...|Thu Mar 22 01:43:...|  en|@ryanryeguy89 @Di...|  D. Michael Massing|    T2DRemission|               962.0|             787.0|Rockville, Connec...|I read clinical r...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201803.0|USER USER My stor...|  D. Michael Massing|4841628|       Rockville| 4841628|     PPL|              US|      4841628|           CT|          013|         null|         null| 1.176846934085804| 177.75645|Rockville,Connect...|           0|         3|     0|           1|
# |1.058549508748034...|Sat Nov 03 02:40:...|  en|@Advil My grandpa...|Megan Morrill 🏳️‍🌈|     Morrill0011|                64.0|             106.0|           Albany NY|Treacher Collins ...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201811.0|USER My grandpa w...|Megan Morrill 🏳️‍🌈|5106834|          Albany| 5106834|    PPLA|              US|      5106834|           NY|          001|         null|         null|1.3594219696852834| 179.86076|           Albany,NY|           0|         2|     1|           0|
# |1.119301638295097...|Fri Apr 19 18:08:...|  en|Felt creative. Mi...|        lily jo 👽👽|   tattooedfemme|                67.0|             180.0|     White House, TN|#mswarrior, (L)GB...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201904.0|Felt creative. Mi...|        lily jo 👽👽|4667282|     White House| 4667282|     PPL|              US|      4667282|           TN|          165|         null|         null|1.1962982124321768| 165.10776|      White,House,TN|           0|         3|     1|           0|
# |1.043519555430158...|Sat Sep 22 15:17:...|  en|My hand has been ...|            Tyreesha|  TyreeshaaJones|                40.0|              70.0|     Jewett City, CT|Mother to Azaria ...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201809.0|My hand has been ...|            Tyreesha|4836993|     Jewett City| 4836993|     PPL|              US|      4836993|           CT|          011|         null|         null|1.1506065016071148| 182.13715|      Jewett,City,CT|           0|         3|     1|           1|
# |9.366932606717337...|Fri Dec 01 20:27:...|  en|This is beautiful...|       Rosie 🧚🏻‍♀️|    RosieMarsh95|               274.0|             417.0|         Suffolk, UK|   22 #type1diabetic|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201712.0|This is beautiful...|       Rosie 🧚🏻‍♀️|4951305|    South Boston| 4951305|    PPLX|              US|      4951305|           MA|          025|         null|         null|1.5272989567794863| 148.00824|          Suffolk,UK|           0|         2|     1|           1|
# |1.010951174990848E18|Sun Jun 24 18:21:...|  en|Something I didn’...|babynurse_extrord...|    msmctadros16|                18.0|              86.0|      Binghamton, NY|20-something CVIC...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201806.0|Something I didn’...|babynurse_extrord...|5109177|      Binghamton| 5109177|   PPLA2|              US|      5109177|           NY|          007|         null|         null|1.2933678235085577| 194.93431|       Binghamton,NY|           0|         2|     1|           1|
# |9.933190461699809...|Mon May 07 02:38:...|  en|@JWonggg I'm diab...|          Chef Lu Bu|      Chef_Lu_Bu|              9433.0|            3209.0|         Atlanta, Ga|http://youtube.co...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201805.0|USER I'm diabetic...|          Chef Lu Bu|4180439|         Atlanta| 4180439|    PPLA|              US|      4180439|           GA|          121|         null|         null| 1.506870518358203| 174.62868|          Atlanta,Ga|           0|         2|     0|           0|
# |1.037475184918388...|Wed Sep 05 22:58:...|  en|This shouldn't ha...|       Howard Kramen|    HowardKramen|               307.0|             668.0|        Richmond, VA|Husband, father, ...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201809.0|This shouldn't ha...|       Howard Kramen|4781708|        Richmond| 4781708|    PPLA|              US|      4781708|           VA|          760|         null|         null|1.4347090320881686| 207.68173|         Richmond,VA|           0|         2|     0|           1|
# |1.140305736137711...|Sun Jun 16 17:10:...|  en|@JeffreeStar I wa...|     Bianca Corrales| lovelybiancaaaa|                48.0|             140.0|          Fresno, CA|https://www.insta...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201906.0|USER I wasn’t abl...|     Bianca Corrales|5350937|          Fresno| 5350937|   PPLA2|              US|      5350937|           CA|          019|         null|         null|1.5180730393923065| 256.66367|           Fresno,CA|           0|         2|     1|           2|
# |8.706813303332536...|Fri Jun 02 16:39:...|  en|it's #NationalDon...|               =ger=|    fnjerseygirl|               406.0|             269.0|          Tucson, AZ|originally from j...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201706.0|it's #NationalDon...|               =ger=|5318313|          Tucson| 5318313|   PPLA2|              US|      5318313|           AZ|          019|         null|         null|1.5202358699339793|   296.147|           Tucson,AZ|           0|         2|     2|           1|
# |8.818716267820277...|Mon Jul 03 13:45:...|  en|@RedTRaccoon #Fre...|Witch Hunt? 😳LMAO😂|     4fun4now4me|              1342.0|            1436.0|        Savannah, GA|#MAGA by deportin...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201707.0|USER #FreedomOfHe...|Witch Hunt? 😳LMAO😂|4221552|        Savannah| 4221552|   PPLA2|              US|      4221552|           GA|          051|         null|         null| 1.395551935608103| 229.73694|         Savannah,GA|           0|         2|     2|           2|
# |1.127419786579861...|Sun May 12 03:46:...|  en|@TempesttStorm I'...|  Shannon the Grouch| GrumpCurmudgeon|               103.0|             534.0|         Atlanta, GA|Grumpy. Curmudgeo...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201905.0|USER I'm diabetic...|  Shannon the Grouch|4180439|         Atlanta| 4180439|    PPLA|              US|      4180439|           GA|          121|         null|         null| 1.506870518358203|  281.8366|          Atlanta,GA|           0|         2|     1|           2|
# |1.047358080873156...|Wed Oct 03 05:30:...|  en|sometimes i forge...|           ash¹²⁷ 🚀|  minhyukslatina|               550.0|             130.0|       San Diego, CA|☀️ || ride or die...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201810.0|sometimes i forge...|           ash¹²⁷ 🚀|5391811|       San Diego| 5391811|   PPLA2|              US|      5391811|           CA|          073|         null|         null|1.6155496613885283| 335.16287|        San,Diego,CA|           0|         3|     2|           0|
# |1.045714582679969...|Fri Sep 28 16:39:...|  en|@janefranklin55 @...|      RethinkThePink| RethinkThePink1|               426.0|             280.0|      Santa Cruz, CA|Refugee from news...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201809.0|USER USER USER US...|      RethinkThePink|5407529|     Watsonville| 5407529|     PPL|              US|      5407529|           CA|          087|         null|         null| 1.306080890401825| 226.60808|       Santa,Cruz,CA|           0|         3|     2|           0|
# |1.108834828852457...|Thu Mar 21 20:56:...|  en|Starting this eve...|🆂🅾🅼🅴🏴‍☠️🅶🆄🆈™|         JWH1895|               593.0|             748.0|The Canadian Prai...|More red flags th...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201903.0|Starting this eve...|🆂🅾🅼🅴🏴‍☠️🅶🆄🆈™|4556165|           Yukon| 4556165|     PPL|              US|      4556165|           OK|          017|         null|         null| 1.248826970841795| 143.67723|The,Canadian,Prai...|           0|         3|     2|           0|
# |9.083079026073190...|Thu Sep 14 12:34:...|  en|I'm more afraid o...|      Easton Ressler|   EastonRassler|               167.0|             123.0|         Solon, Iowa|Lets Play Some Cr...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201709.0|I'm more afraid o...|      Easton Ressler|4876867|           Solon| 4876867|     PPL|              US|      4876867|           IA|          103|         null|         null|1.1437077458800524| 142.42712|          Solon,Iowa|           0|         2|     1|           0|
# |1.133076406114684...|Mon May 27 18:24:...|  en|im sick and tired...|  Courtney O'Donnell|  thisiscourtnay|               347.0|             573.0|        New York, NY|comedian // found...|           null|               null|                      null|                          null|                        null|                   null|                      null|                     null|          null|    201905.0|im sick and tired...|  Courtney O'Donnell|5128581|   New York City| 5128581|     PPL|              US|      5128581|           NY|         null|         null|         null|1.7917830017891763|  415.0096|         New,York,NY|           0|         3|     1|           1|
# +--------------------+--------------------+----+--------------------+--------------------+----------------+--------------------+------------------+--------------------+--------------------+---------------+-------------------+--------------------------+------------------------------+----------------------------+-----------------------+--------------------------+-------------------------+--------------+------------+--------------------+--------------------+-------+----------------+--------+--------+----------------+-------------+-------------+-------------+-------------+-------------+------------------+----------+--------------------+------------+----------+------+------------+
# only showing top 20 rows
#
# None

# %%
#data.sample(n=1000).head()
sample_data = data.sample(0.021)
print(sample_data.count())
sample_data.write.mode("overwrite").parquet("/home/adrian/PhD/Data/Tweets20190708/matching-tweets_diab_noRT-noBots_personal_noJokes_locationUS_geoCityCodeNotNull_emotions_gender-typeDiab_repartition6_sample1000.parquet")
# Out:
# 1002

# %% [markdown]
# ## add column with child mesh classes to dataset

# %%
meshcodes= {'D003920': {'MN': 'C19.246', 'MH': 'Diabetes Mellitus'},
 'D003923': {'MN': 'C19.246.300.500', 'MH': 'Diabetes Mellitus, Lipoatrophic'},
 'D003924': {'MN': 'C19.246.300', 'MH': 'Diabetes Mellitus, Type 2'},
 'D003925': {'MN': 'C19.246.099.500', 'MH': 'Diabetic Angiopathies'},
 'D003926': {'MN': 'C19.246.099.750', 'MH': 'Diabetic Coma'},
 'D003928': {'MN': 'C19.246.099.875', 'MH': 'Diabetic Nephropathies'},
 'D003929': {'MN': 'C19.246.099.937', 'MH': 'Diabetic Neuropathies'},
 'D003930': {'MN': 'C19.246.099.500.382', 'MH': 'Diabetic Retinopathy'},
 'D006944': {'MN': 'C19.246.099.750.490',
  'MH': 'Hyperglycemic Hyperosmolar Nonketotic Coma'},
 'D011236': {'MN': 'C19.246.774', 'MH': 'Prediabetic State'},
 'D016640': {'MN': 'C19.246.200', 'MH': 'Diabetes, Gestational'},
 'D016883': {'MN': 'C19.246.099.812', 'MH': 'Diabetic Ketoacidosis'},
 'D017719': {'MN': 'C19.246.099.500.191', 'MH': 'Diabetic Foot'},
 'D048909': {'MN': 'C19.246.099', 'MH': 'Diabetes Complications'},
 'D056731': {'MN': 'C19.246.537', 'MH': 'Donohue Syndrome'},
 'D058065': {'MN': 'C19.246.099.625', 'MH': 'Diabetic Cardiomyopathies'},
 'D000071698': {'MN': 'C19.246.656',
  'MH': 'Latent Autoimmune Diabetes in Adults'},
 'D014929': {'MN': 'C19.246.267.960', 'MH': 'Wolfram Syndrome'},
 'D003922': {'MN': 'C19.246.267', 'MH': 'Diabetes Mellitus, Type 1'},
 'D003921': {'MN': 'C19.246.240', 'MH': 'Diabetes Mellitus, Experimental'},
 'D005320': {'MN': 'C19.246.099.968', 'MH': 'Fetal Macrosomia'}}

# %%
mesh_hierarchy = {
    "D003920" : {"MH" : 'Diabetes Mellitus',"MN" : 'C19.246', "children": [
            {"D048909" : {'MN': 'C19.246.099', 'MH': 'Diabetes Complications', "children": [{
                "D003925" : {'MN': 'C19.246.099.500', 'MH': 'Diabetic Angiopathies', "children" : [{
                    "D017719" : {'MN': 'C19.246.099.500.191', 'MH': 'Diabetic Foot', "children" : []}
                    , "D003930" : {'MN': 'C19.246.099.500.382', 'MH': 'Diabetic Retinopathy', "children" : []}
                }]}
                , "D058065" : {'MN': 'C19.246.099.625', 'MH': 'Diabetic Cardiomyopathies', "children":[]}
                , "D003926" : {'MN': 'C19.246.099.750', 'MH': 'Diabetic Coma', "children":[{
                    "D006944" : {'MN': 'C19.246.099.750.490', 'MH': 'Hyperglycemic Hyperosmolar Nonketotic Coma', "children": []}
                }]}
                , "D016883" : {'MN': 'C19.246.099.812', 'MH': 'Diabetic Ketoacidosis', "children": []}
                , "D003928" : {'MN': 'C19.246.099.875', 'MH': 'Diabetic Nephropathies', "children": []}
                , "D003929" : {'MN': 'C19.246.099.937', 'MH': 'Diabetic Neuropathies', "children": [{
                    "D017719" : {'MN': 'C19.246.099.937.250', 'MH': 'Diabetic Foot', "children" : []}
                }]}
                , "D005320" : {'MN': 'C19.246.099.968', 'MH': 'Fetal Macrosomia', "children":[]}
            }] }
             , "D016640" : {'MN': 'C19.246.200', 'MH': 'Diabetes, Gestational', "children": []}
             , "D003921" : {'MN': 'C19.246.240', 'MH': 'Diabetes Mellitus, Experimental', "children":[]}
             , "D003922" : {'MN': 'C19.246.267', 'MH': 'Diabetes Mellitus, Type 1', "children":[{
                 "D014929" : {'MN': 'C19.246.267.960', 'MH': 'Wolfram Syndrome', "children":[]}
             }]}
             , "D003924" : {'MN': 'C19.246.300', 'MH': 'Diabetes Mellitus, Type 2', "children":[{
                 'D003923': {'MN': 'C19.246.300.500', 'MH': 'Diabetes Mellitus, Lipoatrophic', "children":[]}
             }]}
             , "D056731" : {'MN': 'C19.246.537', 'MH': 'Donohue Syndrome', "children":[]}
             , "D000071698" : {'MN': 'C19.246.656', 'MH': 'Latent Autoimmune Diabetes in Adults', "children": []}
             , "D011236" : {'MN': 'C19.246.774', 'MH': 'Prediabetic State', "children" : []}
             
            }
        ]
    }
}
#mesh_hierarchy

# %%
mesh_with_parents = {
 'D003923': ["D003924"],
 'D003924': [],
 'D003925': ["D048909"],
 'D003926': ["D048909"],
 'D003928': ["D048909"],
 'D003929': ["D048909"],
 'D003930': ["D048909","D003925"],
 'D006944': ["D003926", "D048909"],
 'D011236': [],
 'D016640': [],
 'D016883': ["D048909"],
 'D017719': ["D003925", "D003929", "D048909"],
 'D048909': [],
 'D056731': [],
 'D058065': ["D048909"],
 'D000071698': [],
 'D014929': ["D003922"],
 'D003922': [],
 'D003921': [],
 'D005320': ["D048909"]
}
"""
mesh_childs = {
 'D003923': [],
 'D003924': ["D003923"],
 'D003925': ["D017719", "D003930"],
 'D003926': ["D006944"],
 'D003928': [],
 'D003929': ["D017719"],
 'D003930': [],
 'D006944': [],
 'D011236': [],
 'D016640': [],
 'D016883': [],
 'D017719': [],
 'D048909': ["D003925", "D017719", "D003930", "D058065", "D003926", "D006944", "D016883", "D003928", "D003929", "D017719", "D005320" ],
 'D056731': [],
 'D058065': [],
 'D000071698': [],
 'D014929': [],
 'D003922': ["D014929"],
 'D003921': [],
 'D005320': []
}
"""
# Out:
# '\nmesh_childs = {\n \'D003923\': [],\n \'D003924\': ["D003923"],\n \'D003925\': ["D017719", "D003930"],\n \'D003926\': ["D006944"],\n \'D003928\': [],\n \'D003929\': ["D017719"],\n \'D003930\': [],\n \'D006944\': [],\n \'D011236\': [],\n \'D016640\': [],\n \'D016883\': [],\n \'D017719\': [],\n \'D048909\': ["D003925", "D017719", "D003930", "D058065", "D003926", "D006944", "D016883", "D003928", "D003929", "D017719", "D005320" ],\n \'D056731\': [],\n \'D058065\': [],\n \'D000071698\': [],\n \'D014929\': [],\n \'D003922\': ["D014929"],\n \'D003921\': [],\n \'D005320\': []\n}\n'

# %%
import pandas as pd
data = pd.read_parquet("/home/adrian/PhD/Data/Pubmed/baseline_diabetes_unique_maxNperClass5000_withoutRootClassDiabetesMellitus.parquet")
data.head()
# Out:
#        PMID                                              title  \
# 0  28800712  Outcomes Achieved With Use of a Prefabricated ...
# 1   6989594  Investigation of insulin sensitivity in early ...
# 2    524360  Ultrastructural pathology of peripheral nerves...
# 3  21199315  Evidence-based interventional pain medicine ac...
# 4  24607755  Delivery timing and cesarean delivery risk in ...
#
#                                             abstract     date  \
# 0  BACKGROUND\nThe total contact cast (TCC) is co...  2017-10
# 1  Twenty-three normal weight subjects without an...  1980-01
# 2  Sural nerve lesions in patients with clinicall...  1979-12
# 3  In the industrialized world, polyneuropathy in...     2011
# 4  OBJECTIVE\nThe purpose of this study was to ev...  2014-09
#
#                                              mesh_ui  \
# 0  D000328,D000367,D000368,D000369,D002370,D01533...
# 1  D001786,D001835,D005230,D005951,D006801,D00732...
# 2  D000328,D001369,D003929,D006801,D008297,D00887...
# 3            D000698,D000700,D003929,D019317,D006801
# 4  D000328,D002585,D016640,D005260,D005865,D00680...
#
#                                              mesh_mh mesh_ui_diab  \
# 0  Adult,Age Factors,Aged,Aged, 80 and over,Casts...      D017719
# 1  Blood Glucose,Body Weight,Fatty Acids, Noneste...      D011236
# 2  Adult,Axons,Diabetic Neuropathies,Humans,Male,...      D003929
# 3  Analgesia,Analgesics,Diabetic Neuropathies,Evi...      D003929
# 4  Adult,Cesarean Section,Diabetes, Gestational,F...      D016640
#
#             mesh_mh_diab                                title_abstract_prep  \
# 0          Diabetic Foot  outcomes achieved with use of a prefabricated ...
# 1      Prediabetic State  investigation of insulin sensitivity in early ...
# 2  Diabetic Neuropathies  ultrastructural pathology of peripheral nerves...
# 3  Diabetic Neuropathies  evidence-based interventional pain medicine ac...
# 4  Diabetes, Gestational  delivery timing and cesarean delivery risk in ...
#
#                                                  vec  \
# 0  [-0.1456865, 0.10184939, 0.08282469, 0.0834905...
# 1  [-0.13539475, 0.06387955, 0.0704756, 0.1377651...
# 2  [-0.13219672, 0.107427344, 0.012001918, 0.0821...
# 3  [-0.15465583, 0.120985754, 0.11113819, 0.06654...
# 4  [-0.080492444, 0.1405143, 0.00491666, 0.153142...
#
#       mesh_ui_diab_with_childs
# 0  [D003925, D003929, D048909]
# 1                           []
# 2                    [D048909]
# 3                    [D048909]
# 4                           []

# %%
#data.to_parquet("/home/adrian/PhD/Data/Pubmed/baseline_diabetes_unique_maxNperClass5000_withoutRootClassDiabetesMellitus_backup.parquet")

# %%
data["mesh_ui_diab_with_childs"] = data["mesh_ui_diab"].map(lambda mesh: mesh_with_parents[mesh])
print(data.shape)
data.head(5)
# Out:
# (50911, 11)
#        PMID                                              title  \
# 0  28800712  Outcomes Achieved With Use of a Prefabricated ...
# 1   6989594  Investigation of insulin sensitivity in early ...
# 2    524360  Ultrastructural pathology of peripheral nerves...
# 3  21199315  Evidence-based interventional pain medicine ac...
# 4  24607755  Delivery timing and cesarean delivery risk in ...
#
#                                             abstract     date  \
# 0  BACKGROUND\nThe total contact cast (TCC) is co...  2017-10
# 1  Twenty-three normal weight subjects without an...  1980-01
# 2  Sural nerve lesions in patients with clinicall...  1979-12
# 3  In the industrialized world, polyneuropathy in...     2011
# 4  OBJECTIVE\nThe purpose of this study was to ev...  2014-09
#
#                                              mesh_ui  \
# 0  D000328,D000367,D000368,D000369,D002370,D01533...
# 1  D001786,D001835,D005230,D005951,D006801,D00732...
# 2  D000328,D001369,D003929,D006801,D008297,D00887...
# 3            D000698,D000700,D003929,D019317,D006801
# 4  D000328,D002585,D016640,D005260,D005865,D00680...
#
#                                              mesh_mh mesh_ui_diab  \
# 0  Adult,Age Factors,Aged,Aged, 80 and over,Casts...      D017719
# 1  Blood Glucose,Body Weight,Fatty Acids, Noneste...      D011236
# 2  Adult,Axons,Diabetic Neuropathies,Humans,Male,...      D003929
# 3  Analgesia,Analgesics,Diabetic Neuropathies,Evi...      D003929
# 4  Adult,Cesarean Section,Diabetes, Gestational,F...      D016640
#
#             mesh_mh_diab                                title_abstract_prep  \
# 0          Diabetic Foot  outcomes achieved with use of a prefabricated ...
# 1      Prediabetic State  investigation of insulin sensitivity in early ...
# 2  Diabetic Neuropathies  ultrastructural pathology of peripheral nerves...
# 3  Diabetic Neuropathies  evidence-based interventional pain medicine ac...
# 4  Diabetes, Gestational  delivery timing and cesarean delivery risk in ...
#
#                                                  vec  \
# 0  [-0.1456865, 0.10184939, 0.08282469, 0.0834905...
# 1  [-0.13539475, 0.06387955, 0.0704756, 0.1377651...
# 2  [-0.13219672, 0.107427344, 0.012001918, 0.0821...
# 3  [-0.15465583, 0.120985754, 0.11113819, 0.06654...
# 4  [-0.080492444, 0.1405143, 0.00491666, 0.153142...
#
#       mesh_ui_diab_with_childs
# 0  [D003925, D003929, D048909]
# 1                           []
# 2                    [D048909]
# 3                    [D048909]
# 4                           []

# %%
data.to_parquet("/home/adrian/PhD/Data/Pubmed/baseline_diabetes_unique_maxNperClass5000_withoutRootClassDiabetesMellitus.parquet")

# %% [markdown]
# ## Get subsets of data

# %%
import pandas as pd 
data = pd.read_parquet("/home/adrian/PhD/Data/Pubmed/baseline_diabetes_unique_maxNperClass5000_withoutRootClassDiabetesMellitus.parquet")
print(data.shape)
data.head(1)
# Out:
# (50911, 11)
#        PMID                                              title  \
# 0  28800712  Outcomes Achieved With Use of a Prefabricated ...
#
#                                             abstract     date  \
# 0  BACKGROUND\nThe total contact cast (TCC) is co...  2017-10
#
#                                              mesh_ui  \
# 0  D000328,D000367,D000368,D000369,D002370,D01533...
#
#                                              mesh_mh mesh_ui_diab  \
# 0  Adult,Age Factors,Aged,Aged, 80 and over,Casts...      D017719
#
#     mesh_mh_diab                                title_abstract_prep  \
# 0  Diabetic Foot  outcomes achieved with use of a prefabricated ...
#
#                                                  vec  \
# 0  [-0.1456865, 0.10184939, 0.08282469, 0.0834905...
#
#       mesh_ui_diab_with_childs
# 0  [D003925, D003929, D048909]

# %%
diab_gestational = data[data["mesh_ui_diab"] == "D016640"].sample(n=1000, random_state=0)
diab_nonGestational = data[data["mesh_ui_diab"] != "D016640"].sample(n=1000, random_state=0)
diab_gestational_nonGestational = diab_gestational.append(diab_nonGestational).sample(frac=1).reset_index(drop=True)

diab_complications = data[data["mesh_ui_diab"] == "D048909"].sample(n=1000, random_state=0)
diab_nonComplications = data[data["mesh_ui_diab"] != "D048909"].sample(n=1000, random_state=0)
diab_complications_nonComplications = diab_complications.append(diab_nonComplications).sample(frac=1).reset_index(drop=True)

data_2000_random = data.sample(n=2000, random_state=0).reset_index(drop=True) # 62
data_5000_random = data.sample(n=5000, random_state=0).reset_index(drop=True)
data_10000_random = data.sample(n=10000, random_state=0).reset_index(drop=True)
data_20000_random = data.sample(n=20000, random_state=0).reset_index(drop=True)
data_30000_random = data.sample(n=30000, random_state=0).reset_index(drop=True)
data_40000_random = data.sample(n=40000, random_state=0).reset_index(drop=True)
data_50000_random = data.sample(n=50000, random_state=0).reset_index(drop=True)

# %%
posClass = "D003930"

def mesh_to_boolean(x):
    mesh, meshChilds = x
    if (mesh == posClass or posClass in meshChilds): 
        return True
    else:
        return False

def get_N_posAndNeg(data):
    dataToBool = data[["mesh_ui_diab", "mesh_ui_diab_with_childs"]].apply(mesh_to_boolean , axis=1) 
    return dataToBool.groupby(dataToBool).count()

#print("N pos + N neg abstracts:")
#dataToBool = data_2000_random[["mesh_ui_diab", "mesh_ui_diab_with_childs"]].apply(mesh_to_boolean , axis=1) 
#print(dataToBool.groupby(dataToBool).count())
print(get_N_posAndNeg(data_2000_random))
get_N_posAndNeg(data_2000_random).loc[True]
# Out:
# False    1815
# True      185
# dtype: int64
# 185

# %%
from sklearn.model_selection import train_test_split
#y_test = test["mesh_ui_diab"].map(lambda mesh: 1 if mesh == "D048909" else 0).values
#X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.75, random_state=0)

train, test = train_test_split(data_2000_random, test_size=0.5, random_state=0) # 17:130
print("train:")
print(get_N_posAndNeg(train))
print("\ntest:")
print(get_N_posAndNeg(test))
# Out:
# train:
# False    899
# True     101
# dtype: int64
#
# test:
# False    916
# True      84
# dtype: int64

# %%
#train = X_train
#train["true_label"] = y_train
train.reset_index(drop=True).to_parquet("/home/adrian/workspace/ActiveLearning/Active-Learning-for-Neural-Networks/data/diabetes/2000_random/2000random_1000train.parquet")
#test = X_test
#test["true_label"] = y_test
test.reset_index(drop=True).to_parquet("/home/adrian/workspace/ActiveLearning/Active-Learning-for-Neural-Networks/data/diabetes/2000_random/2000random_1000train.parquet")

# %%
dirpath = "/home/adrian/workspace/ActiveLearning/Active-Learning-for-Neural-Networks/data/diabetes"
#subdir_gest = dirpath+"/gestational_1000pos_and_neg_samples/"
#subdir_complications = dirpath+"/complications_100pos_and_neg_samples/"
#(diab_gestational.title + " " + diab_gestational.abstract).map(lambda s: s.replace('\n', '')).to_csv(subdir_gest+"diab_gestational_1000samples.txt", index=False, header=False)
#(diab_nonGestational.title + " " + diab_nonGestational.abstract).map(lambda s: s.replace('\n', '')).to_csv(subdir_gest+"diab_Nongestational_1000samples.txt", index=False, header=False)
#(diab_gestational.title ).map(lambda s: s.replace('\n', '')).to_csv(dirpath+"/gestational_1000pos_and_neg_samples_onlyTitles/diab_gestational_1000samples_onlyTitles.txt", index=False, header=False)
#(diab_nonGestational.title).map(lambda s: s.replace('\n', '')).to_csv(dirpath+"/gestational_1000pos_and_neg_samples_onlyTitles/diab_Nongestational_1000samples_onlyTitles.txt", index=False, header=False)
#(diab_complications.title + " " + diab_complications.abstract).map(lambda s: s.replace('\n', '')).to_csv(subdir_complications+"/diab_complications_1000samples.txt", index=False, header=False)
#(diab_nonComplications.title + " " + diab_nonComplications.abstract).map(lambda s: s.replace('\n', '')).to_csv(subdir_complications+"/diab_nonComplications_1000samples.txt", index=False, header=False)
#(diab_complications.title ).map(lambda s: s.replace('\n', '')).to_csv(dirpath+"/complications_1000pos_and_neg_samples_onlyTitles/diab_complications_1000samples_onlyTitles.txt", index=False, header=False)
#(diab_nonComplications.title).map(lambda s: s.replace('\n', '')).to_csv(dirpath+"/complications_1000pos_and_neg_samples_onlyTitles/diab_nonComplications_1000samples_onlyTitles.txt", index=False, header=False)

#diab_gestational_nonGestational.to_parquet(subdir_gest+"data.parquet")
#diab_complications_nonComplications.to_parquet(subdir_complications+"data.parquet")
#diab_complications_nonComplications.to_parquet("/home/adrian/workspace/Hierarchical-Clustering-Active-Learning-Text/tmp/complications_1000pos_and_neg_samples.parquet")
data_2000_random.to_parquet(dirpath+"/2000_random/2000_random_abstracts.parquet")
#data_5000_random.to_parquet(dirpath+"/5000_random/5000_random_abstracts.parquet")
#dirpath = "/home/adrian/PhD/Data/Pubmed/baseline_diabetes_unique_maxNperClass5000_withoutRootClassDiabetesMellitus"
#data_5000_random.to_parquet(dirpath+"_sample5000.parquet")
#data_10000_random.to_parquet(dirpath+"_sample10000.parquet")
#data_20000_random.to_parquet(dirpath+"_sample20000.parquet")
#data_30000_random.to_parquet(dirpath+"_sample30000.parquet")
#data_40000_random.to_parquet(dirpath+"_sample40000.parquet")
#data_50000_random.to_parquet(dirpath+"_sample50000.parquet")
